# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
sns.set(context="notebook", palette="Spectral", style = 'darkgrid' ,font_scale = 1.5, color_codes=True)
import warnings
warnings.filterwarnings('ignore')
import os
import matplotlib.pyplot as plt

# %%
abc=pd.read_csv('C:\\Users\\Kartik\\OneDrive\\Desktop\\train.csv')

# %%
abc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478741 entries, 0 to 478740
# Data columns (total 27 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Accident_ID                                  478741 non-null  int64
#  1   Police_Force                                 478741 non-null  int64
#  2   Number_of_Vehicles                           478741 non-null  int64
#  3   Number_of_Casualties                         478741 non-null  int64
#  4   Date                                         478741 non-null  object
#  5   Day_of_Week                                  478741 non-null  int64
#  6   Time                                         478727 non-null  object
#  7   Local_Authority_(District)                   478741 non-null  int64
#  8   Local_Authority_(Highway)                    478741 non-null  object
#  9   1st_Road_Class                               478741 non-null  int64
#  10  1st_Road_Number                              478741 non-null  int64
#  11  Road_Type                                    478741 non-null  object
#  12  Speed_limit                                  478741 non-null  int64
#  13  2nd_Road_Class                               478741 non-null  int64
#  14  2nd_Road_Number                              478741 non-null  int64
#  15  Pedestrian_Crossing-Human_Control            478741 non-null  object
#  16  Pedestrian_Crossing-Physical_Facilities      478741 non-null  object
#  17  Light_Conditions                             478741 non-null  object
#  18  Weather_Conditions                           478741 non-null  object
#  19  Road_Surface_Conditions                      478289 non-null  object
#  20  Special_Conditions_at_Site                   478678 non-null  object
#  21  Carriageway_Hazards                          478741 non-null  object
#  22  Urban_or_Rural_Area                          478741 non-null  int64
#  23  Did_Police_Officer_Attend_Scene_of_Accident  478741 non-null  object
#  24  state                                        478741 non-null  object
#  25  postcode                                     478741 non-null  object
#  26  country                                      478741 non-null  object
# dtypes: int64(12), object(15)
# memory usage: 98.6+ MB

# %%
abc.describe()
# Out:
#          Accident_ID   Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# count  478741.000000  478741.000000       478741.000000         478741.000000
# mean   299892.954673      31.610178            1.745695              1.463528
# std    173261.274950      24.941660            0.626458              0.816019
# min         1.000000       1.000000            1.000000              1.000000
# 25%    149718.000000      12.000000            1.000000              1.000000
# 50%    299791.000000      33.000000            2.000000              1.000000
# 75%    449990.000000      45.000000            2.000000              2.000000
# max    599999.000000      98.000000            4.000000              5.000000
#
#          Day_of_Week  Local_Authority_(District)  1st_Road_Class  \
# count  478741.000000               478741.000000   478741.000000
# mean        4.367898                  357.457132        4.381542
# std         1.872983                  256.530105        1.369579
# min         1.000000                    1.000000        1.000000
# 25%         3.000000                  103.000000        3.000000
# 50%         5.000000                  314.000000        4.000000
# 75%         6.000000                  521.000000        6.000000
# max         7.000000                  941.000000        6.000000
#
#        1st_Road_Number    Speed_limit  2nd_Road_Class  2nd_Road_Number  \
# count    478741.000000  478741.000000   478741.000000         478741.0
# mean        946.663375      37.035976        2.430068              0.0
# std        1730.926876      12.854299        3.268563              0.0
# min           0.000000      20.000000       -1.000000              0.0
# 25%          10.000000      30.000000       -1.000000              0.0
# 50%         336.000000      30.000000        3.000000              0.0
# 75%         569.000000      40.000000        6.000000              0.0
# max        9832.000000      70.000000        6.000000              0.0
#
#        Urban_or_Rural_Area
# count        478741.000000
# mean              1.402050
# std               0.490313
# min               1.000000
# 25%               1.000000
# 50%               1.000000
# 75%               2.000000
# max               2.000000

# %%
p = sns.pairplot(abc)

# %%
abc.head(15)
# Out:
#     Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0             1            34                   2                     1
# 1             2             5                   2                     1
# 2             3             1                   2                     1
# 3             4             1                   1                     1
# 4             5            46                   1                     1
# 5             6            44                   2                     1
# 6             7            43                   2                     1
# 7             8            43                   2                     1
# 8             9            42                   2                     3
# 9            10             6                   2                     1
# 10           11             7                   2                     1
# 11           12            43                   1                     1
# 12           13            15                   2                     1
# 13           15            21                   1                     2
# 14           16             6                   2                     1
#
#         Date  Day_of_Week   Time  Local_Authority_(District)  \
# 0   19/12/12            7  13:20                         344
# 1   02/11/12            4   7:53                         102
# 2   02/11/12            4  16:00                         531
# 3   06/05/12            1  16:50                           7
# 4   30/06/12            3  13:25                         519
# 5   04/03/12            1  12:31                         638
# 6   11/04/12            2  14:44                         502
# 7   06/06/12            2  21:43                         529
# 8   27/03/12            6  13:30                         489
# 9   13/09/12            6  17:25                          95
# 10  04/02/12            5  16:40                          87
# 11  09/11/12            4  13:05                         521
# 12  08/01/12            7   8:00                         305
# 13  19/01/12            7  19:35                         279
# 14  22/06/12            3  18:40                          87
#
#    Local_Authority_(Highway)  1st_Road_Class  ...  \
# 0                  E10000032               4  ...
# 1                  E09000026               3  ...
# 2                  E10000016               6  ...
# 3                  E08000035               6  ...
# 4                  E10000031               3  ...
# 5                  W06000004               6  ...
# 6                  E06000049               5  ...
# 7                  S12000019               3  ...
# 8                  E10000016               4  ...
# 9                  E06000050               4  ...
# 10                 E09000025               6  ...
# 11                 E06000048               6  ...
# 12                 E10000029               5  ...
# 13                 E06000046               4  ...
# 14                 E06000009               3  ...
#
#                            Light_Conditions          Weather_Conditions  \
# 0            Daylight: Street light present     Fine without high winds
# 1            Daylight: Street light present  Raining without high winds
# 2            Daylight: Street light present     Fine without high winds
# 3            Daylight: Street light present     Fine without high winds
# 4            Daylight: Street light present     Fine without high winds
# 5         Darkness: Street lighting unknown  Raining without high winds
# 6            Daylight: Street light present     Fine without high winds
# 7            Daylight: Street light present     Fine without high winds
# 8            Daylight: Street light present     Fine without high winds
# 9            Daylight: Street light present     Fine without high winds
# 10           Daylight: Street light present     Fine without high winds
# 11  Darkness: Street lights present and lit     Fine without high winds
# 12  Darkness: Street lights present and lit     Fine without high winds
# 13  Darkness: Street lights present and lit  Raining without high winds
# 14           Daylight: Street light present     Fine without high winds
#
#     Road_Surface_Conditions  Special_Conditions_at_Site  Carriageway_Hazards  \
# 0                       Dry                Ol or diesel                 None
# 1                       Dry                        None                 None
# 2                       Dry                        None                 None
# 3                       Dry                   Roadworks                 None
# 4                       Dry                        None                 None
# 5                       Dry                        None                 None
# 6                       Dry                        None                 None
# 7                       Dry                   Roadworks                 None
# 8                       Dry                        None                 None
# 9                       Dry                        None                 None
# 10                      Dry                        None                 None
# 11                      Dry                        None                 None
# 12                      Dry                        None                 None
# 13                      Dry                        None                 None
# 14                      Dry                        None                 None
#
#    Urban_or_Rural_Area Did_Police_Officer_Attend_Scene_of_Accident  \
# 0                    1                                         Yes
# 1                    1                                          No
# 2                    1                                          No
# 3                    1                                         Yes
# 4                    1                                          No
# 5                    1                                         Yes
# 6                    1                                         Yes
# 7                    2                                         Yes
# 8                    1                                         Yes
# 9                    1                                         Yes
# 10                   1                                         Yes
# 11                   1                                         Yes
# 12                   1                                         Yes
# 13                   2                                         Yes
# 14                   1                                         Yes
#
#               state  postcode         country
# 0           England   OX3 9UP  United Kingdom
# 1           England   S35 4EZ  United Kingdom
# 2           England  BN21 2XR  United Kingdom
# 3           England  TA20 3PT  United Kingdom
# 4           England  DN20 0QF  United Kingdom
# 5           England  OL11 1NH  United Kingdom
# 6           England    E5 9QH  United Kingdom
# 7           England  SO14 0FD  United Kingdom
# 8           England   WS9 8BD  United Kingdom
# 9           England   LA4 4JN  United Kingdom
# 10          England  WA15 8ER  United Kingdom
# 11  Alba / Scotland  RH19 4LD  United Kingdom
# 12          England   IG2 6NW  United Kingdom
# 13          England  KT12 2LZ  United Kingdom
# 14          England   SW6 1LU  United Kingdom
#
# [15 rows x 27 columns]

# %%
abc.tail()
# Out:
#         Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 478736       599995            13                   1                     1
# 478737       599996            13                   2                     1
# 478738       599997             6                   2                     4
# 478739       599998            33                   2                     1
# 478740       599999             1                   2                     1
#
#             Date  Day_of_Week   Time  Local_Authority_(District)  \
# 478736  28/09/12            6  16:35                         199
# 478737  23/01/12            4  20:45                         211
# 478738  15/05/12            6  10:45                          80
# 478739  09/10/12            2  11:22                         321
# 478740  12/04/12            6  11:50                          23
#
#        Local_Authority_(Highway)  1st_Road_Class  ...  \
# 478736                 E10000015               6  ...
# 478737                 E09000012               6  ...
# 478738                 E06000047               3  ...
# 478739                 E10000024               3  ...
# 478740                 E09000025               4  ...
#
#                       Light_Conditions          Weather_Conditions  \
# 478736  Daylight: Street light present     Fine without high winds
# 478737  Daylight: Street light present     Fine without high winds
# 478738  Daylight: Street light present     Fine without high winds
# 478739  Daylight: Street light present     Fine without high winds
# 478740  Daylight: Street light present  Raining without high winds
#
#         Road_Surface_Conditions  Special_Conditions_at_Site  \
# 478736                     Snow                        None
# 478737                 Wet/Damp                        None
# 478738                      Dry                        None
# 478739                      Dry                        None
# 478740                      Dry                        None
#
#                 Carriageway_Hazards Urban_or_Rural_Area  \
# 478736                         None                   2
# 478737                         None                   1
# 478738                         None                   1
# 478739  Other object in carriageway                   2
# 478740                         None                   1
#
#        Did_Police_Officer_Attend_Scene_of_Accident    state  postcode  \
# 478736                                         Yes  England   E12 6EA
# 478737                                          No  England   NN2 8PF
# 478738                                          No  England  DN36 5FR
# 478739                                          No  England  BN11 2EB
# 478740                                         Yes  England  IP10 0AH
#
#                country
# 478736  United Kingdom
# 478737  United Kingdom
# 478738  United Kingdom
# 478739  United Kingdom
# 478740  United Kingdom
#
# [5 rows x 27 columns]

# %%
#Assumptions for Linear Regression
#1. Linearity
#Linear regression needs the relationship between the independent and dependent variables to be linear. Let's use a pair plot to check the relation of independent variables with number causality

# %%
# visualize the relationship between the features and the response using scatterplots
p = sns.pairplot(abc, x_vars=['Number_of_Vehicles','Weather_Conditions','Light_Conditions'], y_vars='Number_of_Casualties', size=20, aspect=0.7)

# %%
#from sklearn import preprocessing

#df.apply(preprocessing.LabelEncoder().fit_transform(df['label']))

# %%
abc.isnull().sum()
# Out:
# Accident_ID                                      0
# Police_Force                                     0
# Number_of_Vehicles                               0
# Number_of_Casualties                             0
# Date                                             0
# Day_of_Week                                      0
# Time                                            14
# Local_Authority_(District)                       0
# Local_Authority_(Highway)                        0
# 1st_Road_Class                                   0
# 1st_Road_Number                                  0
# Road_Type                                        0
# Speed_limit                                      0
# 2nd_Road_Class                                   0
# 2nd_Road_Number                                  0
# Pedestrian_Crossing-Human_Control                0
# Pedestrian_Crossing-Physical_Facilities          0
# Light_Conditions                                 0
# Weather_Conditions                               0
# Road_Surface_Conditions                        452
# Special_Conditions_at_Site                      63
# Carriageway_Hazards                              0
# Urban_or_Rural_Area                              0
# Did_Police_Officer_Attend_Scene_of_Accident      0
# state                                            0
# postcode                                         0
# country                                          0
# dtype: int64

# %%
abc.describe()
# Out:
#          Accident_ID   Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# count  478741.000000  478741.000000       478741.000000         478741.000000
# mean   299892.954673      31.610178            1.745695              1.463528
# std    173261.274950      24.941660            0.626458              0.816019
# min         1.000000       1.000000            1.000000              1.000000
# 25%    149718.000000      12.000000            1.000000              1.000000
# 50%    299791.000000      33.000000            2.000000              1.000000
# 75%    449990.000000      45.000000            2.000000              2.000000
# max    599999.000000      98.000000            4.000000              5.000000
#
#          Day_of_Week  Local_Authority_(District)  1st_Road_Class  \
# count  478741.000000               478741.000000   478741.000000
# mean        4.367898                  357.457132        4.381542
# std         1.872983                  256.530105        1.369579
# min         1.000000                    1.000000        1.000000
# 25%         3.000000                  103.000000        3.000000
# 50%         5.000000                  314.000000        4.000000
# 75%         6.000000                  521.000000        6.000000
# max         7.000000                  941.000000        6.000000
#
#        1st_Road_Number    Speed_limit  2nd_Road_Class  2nd_Road_Number  \
# count    478741.000000  478741.000000   478741.000000         478741.0
# mean        946.663375      37.035976        2.430068              0.0
# std        1730.926876      12.854299        3.268563              0.0
# min           0.000000      20.000000       -1.000000              0.0
# 25%          10.000000      30.000000       -1.000000              0.0
# 50%         336.000000      30.000000        3.000000              0.0
# 75%         569.000000      40.000000        6.000000              0.0
# max        9832.000000      70.000000        6.000000              0.0
#
#        Urban_or_Rural_Area
# count        478741.000000
# mean              1.402050
# std               0.490313
# min               1.000000
# 25%               1.000000
# 50%               1.000000
# 75%               2.000000
# max               2.000000

# %%
abc.shape
# Out:
# (478741, 27)

# %%
abc = abc.dropna(how='any',axis=0)

# %%
abc.isnull().sum()
# Out:
# Accident_ID                                    0
# Police_Force                                   0
# Number_of_Vehicles                             0
# Number_of_Casualties                           0
# Date                                           0
# Day_of_Week                                    0
# Time                                           0
# Local_Authority_(District)                     0
# Local_Authority_(Highway)                      0
# 1st_Road_Class                                 0
# 1st_Road_Number                                0
# Road_Type                                      0
# Speed_limit                                    0
# 2nd_Road_Class                                 0
# 2nd_Road_Number                                0
# Pedestrian_Crossing-Human_Control              0
# Pedestrian_Crossing-Physical_Facilities        0
# Light_Conditions                               0
# Weather_Conditions                             0
# Road_Surface_Conditions                        0
# Special_Conditions_at_Site                     0
# Carriageway_Hazards                            0
# Urban_or_Rural_Area                            0
# Did_Police_Officer_Attend_Scene_of_Accident    0
# state                                          0
# postcode                                       0
# country                                        0
# dtype: int64

# %%
abc.head()
# Out:
#    Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0            1            34                   2                     1
# 1            2             5                   2                     1
# 2            3             1                   2                     1
# 3            4             1                   1                     1
# 4            5            46                   1                     1
#
#        Date  Day_of_Week   Time  Local_Authority_(District)  \
# 0  19/12/12            7  13:20                         344
# 1  02/11/12            4   7:53                         102
# 2  02/11/12            4  16:00                         531
# 3  06/05/12            1  16:50                           7
# 4  30/06/12            3  13:25                         519
#
#   Local_Authority_(Highway)  1st_Road_Class  ...  \
# 0                 E10000032               4  ...
# 1                 E09000026               3  ...
# 2                 E10000016               6  ...
# 3                 E08000035               6  ...
# 4                 E10000031               3  ...
#
#                  Light_Conditions          Weather_Conditions  \
# 0  Daylight: Street light present     Fine without high winds
# 1  Daylight: Street light present  Raining without high winds
# 2  Daylight: Street light present     Fine without high winds
# 3  Daylight: Street light present     Fine without high winds
# 4  Daylight: Street light present     Fine without high winds
#
#    Road_Surface_Conditions  Special_Conditions_at_Site  Carriageway_Hazards  \
# 0                      Dry                Ol or diesel                 None
# 1                      Dry                        None                 None
# 2                      Dry                        None                 None
# 3                      Dry                   Roadworks                 None
# 4                      Dry                        None                 None
#
#   Urban_or_Rural_Area Did_Police_Officer_Attend_Scene_of_Accident    state  \
# 0                   1                                         Yes  England
# 1                   1                                          No  England
# 2                   1                                          No  England
# 3                   1                                         Yes  England
# 4                   1                                          No  England
#
#    postcode         country
# 0   OX3 9UP  United Kingdom
# 1   S35 4EZ  United Kingdom
# 2  BN21 2XR  United Kingdom
# 3  TA20 3PT  United Kingdom
# 4  DN20 0QF  United Kingdom
#
# [5 rows x 27 columns]

# %%
# Import label encoder 
from sklearn import preprocessing
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'Country'. 
abc['Light_Conditions']= label_encoder.fit_transform(abc["Light_Conditions"]) 
print(abc.head())
# Out:
#    Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0            1            34                   2                     1
# 1            2             5                   2                     1
# 2            3             1                   2                     1
# 3            4             1                   1                     1
# 4            5            46                   1                     1
#
#        Date  Day_of_Week   Time  Local_Authority_(District)  \
# 0  19/12/12            7  13:20                         344
# 1  02/11/12            4   7:53                         102
# 2  02/11/12            4  16:00                         531
# 3  06/05/12            1  16:50                           7
# 4  30/06/12            3  13:25                         519
#
#   Local_Authority_(Highway)  1st_Road_Class  ...  Light_Conditions  \
# 0                 E10000032               4  ...                 4
# 1                 E09000026               3  ...                 4
# 2                 E10000016               6  ...                 4
# 3                 E08000035               6  ...                 4
# 4                 E10000031               3  ...                 4
#
#            Weather_Conditions  Road_Surface_Conditions  \
# 0     Fine without high winds                      Dry
# 1  Raining without high winds                      Dry
# 2     Fine without high winds                      Dry
# 3     Fine without high winds                      Dry
# 4     Fine without high winds                      Dry
#
#    Special_Conditions_at_Site  Carriageway_Hazards Urban_or_Rural_Area  \
# 0                Ol or diesel                 None                   1
# 1                        None                 None                   1
# 2                        None                 None                   1
# 3                   Roadworks                 None                   1
# 4                        None                 None                   1
#
#   Did_Police_Officer_Attend_Scene_of_Accident    state  postcode  \
# 0                                         Yes  England   OX3 9UP
# 1                                          No  England   S35 4EZ
# 2                                          No  England  BN21 2XR
# 3                                         Yes  England  TA20 3PT
# 4                                          No  England  DN20 0QF
#
#           country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom
#
# [5 rows x 27 columns]

# %%
abc.head()
# Out:
#    Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0            1            34                   2                     1
# 1            2             5                   2                     1
# 2            3             1                   2                     1
# 3            4             1                   1                     1
# 4            5            46                   1                     1
#
#        Date  Day_of_Week   Time  Local_Authority_(District)  \
# 0  19/12/12            7  13:20                         344
# 1  02/11/12            4   7:53                         102
# 2  02/11/12            4  16:00                         531
# 3  06/05/12            1  16:50                           7
# 4  30/06/12            3  13:25                         519
#
#   Local_Authority_(Highway)  1st_Road_Class  ...  Light_Conditions  \
# 0                 E10000032               4  ...                 4
# 1                 E09000026               3  ...                 4
# 2                 E10000016               6  ...                 4
# 3                 E08000035               6  ...                 4
# 4                 E10000031               3  ...                 4
#
#            Weather_Conditions  Road_Surface_Conditions  \
# 0     Fine without high winds                      Dry
# 1  Raining without high winds                      Dry
# 2     Fine without high winds                      Dry
# 3     Fine without high winds                      Dry
# 4     Fine without high winds                      Dry
#
#    Special_Conditions_at_Site  Carriageway_Hazards Urban_or_Rural_Area  \
# 0                Ol or diesel                 None                   1
# 1                        None                 None                   1
# 2                        None                 None                   1
# 3                   Roadworks                 None                   1
# 4                        None                 None                   1
#
#   Did_Police_Officer_Attend_Scene_of_Accident    state  postcode  \
# 0                                         Yes  England   OX3 9UP
# 1                                          No  England   S35 4EZ
# 2                                          No  England  BN21 2XR
# 3                                         Yes  England  TA20 3PT
# 4                                          No  England  DN20 0QF
#
#           country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom
#
# [5 rows x 27 columns]

# %%
abc.tail()
# Out:
#         Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 478736       599995            13                   1                     1
# 478737       599996            13                   2                     1
# 478738       599997             6                   2                     4
# 478739       599998            33                   2                     1
# 478740       599999             1                   2                     1
#
#             Date  Day_of_Week   Time  Local_Authority_(District)  \
# 478736  28/09/12            6  16:35                         199
# 478737  23/01/12            4  20:45                         211
# 478738  15/05/12            6  10:45                          80
# 478739  09/10/12            2  11:22                         321
# 478740  12/04/12            6  11:50                          23
#
#        Local_Authority_(Highway)  1st_Road_Class  ...  Light_Conditions  \
# 478736                 E10000015               6  ...                 4
# 478737                 E09000012               6  ...                 4
# 478738                 E06000047               3  ...                 4
# 478739                 E10000024               3  ...                 4
# 478740                 E09000025               4  ...                 4
#
#                 Weather_Conditions  Road_Surface_Conditions  \
# 478736     Fine without high winds                     Snow
# 478737     Fine without high winds                 Wet/Damp
# 478738     Fine without high winds                      Dry
# 478739     Fine without high winds                      Dry
# 478740  Raining without high winds                      Dry
#
#         Special_Conditions_at_Site          Carriageway_Hazards  \
# 478736                        None                         None
# 478737                        None                         None
# 478738                        None                         None
# 478739                        None  Other object in carriageway
# 478740                        None                         None
#
#        Urban_or_Rural_Area Did_Police_Officer_Attend_Scene_of_Accident  \
# 478736                   2                                         Yes
# 478737                   1                                          No
# 478738                   1                                          No
# 478739                   2                                          No
# 478740                   1                                         Yes
#
#           state  postcode         country
# 478736  England   E12 6EA  United Kingdom
# 478737  England   NN2 8PF  United Kingdom
# 478738  England  DN36 5FR  United Kingdom
# 478739  England  BN11 2EB  United Kingdom
# 478740  England  IP10 0AH  United Kingdom
#
# [5 rows x 27 columns]

# %%
abc.Light_Conditions.unique()
# Out:
# array([4, 1, 2, 0, 3])

# %%
abc.Weather_Conditions.unique()
# Out:
# array(['Fine without high winds', 'Raining without high winds',
#        'Fine with high winds', 'Raining with high winds', 'Unknown',
#        'Snowing without high winds', 'Snowing with high winds', 'Other',
#        'Fog or mist'], dtype=object)

# %%
# Fitting the linear model
x = abc.drop(["Number_of_Casualties"],axis=1)
y = abc.Number_of_Casualties

# %%
abc.drop(["Local_Authority_(Highway)","Did_Police_Officer_Attend_Scene_of_Accident","state","postcode","country"]
  ,axis= 1, inplace=True)

# %%
abc.head()
# Out:
#    Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0            1            34                   2                     1
# 1            2             5                   2                     1
# 2            3             1                   2                     1
# 3            4             1                   1                     1
# 4            5            46                   1                     1
#
#        Date  Day_of_Week   Time  Local_Authority_(District)  1st_Road_Class  \
# 0  19/12/12            7  13:20                         344               4
# 1  02/11/12            4   7:53                         102               3
# 2  02/11/12            4  16:00                         531               6
# 3  06/05/12            1  16:50                           7               6
# 4  30/06/12            3  13:25                         519               3
#
#    1st_Road_Number  ... 2nd_Road_Class  2nd_Road_Number  \
# 0              395  ...             -1                0
# 1               13  ...             -1                0
# 2                8  ...              6                0
# 3               13  ...              6                0
# 4               24  ...              6                0
#
#    Pedestrian_Crossing-Human_Control  Pedestrian_Crossing-Physical_Facilities  \
# 0              None within 50 metres    No physical crossing within 50 meters
# 1              None within 50 metres    No physical crossing within 50 meters
# 2              None within 50 metres                           Zebra crossing
# 3              None within 50 metres    No physical crossing within 50 meters
# 4              None within 50 metres                           Zebra crossing
#
#   Light_Conditions          Weather_Conditions  Road_Surface_Conditions  \
# 0                4     Fine without high winds                      Dry
# 1                4  Raining without high winds                      Dry
# 2                4     Fine without high winds                      Dry
# 3                4     Fine without high winds                      Dry
# 4                4     Fine without high winds                      Dry
#
#   Special_Conditions_at_Site Carriageway_Hazards Urban_or_Rural_Area
# 0               Ol or diesel                None                   1
# 1                       None                None                   1
# 2                       None                None                   1
# 3                  Roadworks                None                   1
# 4                       None                None                   1
#
# [5 rows x 22 columns]

# %%
abc.drop(["Date"]
  ,axis= 1, inplace=True)

# %%
abc.shape
# Out:
# (478212, 21)

# %%
abc.head()
# Out:
#    Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0            1            34                   2                     1
# 1            2             5                   2                     1
# 2            3             1                   2                     1
# 3            4             1                   1                     1
# 4            5            46                   1                     1
#
#    Day_of_Week   Time  Local_Authority_(District)  1st_Road_Class  \
# 0            7  13:20                         344               4
# 1            4   7:53                         102               3
# 2            4  16:00                         531               6
# 3            1  16:50                           7               6
# 4            3  13:25                         519               3
#
#    1st_Road_Number           Road_Type  ...  2nd_Road_Class  2nd_Road_Number  \
# 0              395  Single carriageway  ...              -1                0
# 1               13      One way street  ...              -1                0
# 2                8          Roundabout  ...               6                0
# 3               13  Single carriageway  ...               6                0
# 4               24    Dual carriageway  ...               6                0
#
#    Pedestrian_Crossing-Human_Control Pedestrian_Crossing-Physical_Facilities  \
# 0              None within 50 metres   No physical crossing within 50 meters
# 1              None within 50 metres   No physical crossing within 50 meters
# 2              None within 50 metres                          Zebra crossing
# 3              None within 50 metres   No physical crossing within 50 meters
# 4              None within 50 metres                          Zebra crossing
#
#   Light_Conditions          Weather_Conditions Road_Surface_Conditions  \
# 0                4     Fine without high winds                     Dry
# 1                4  Raining without high winds                     Dry
# 2                4     Fine without high winds                     Dry
# 3                4     Fine without high winds                     Dry
# 4                4     Fine without high winds                     Dry
#
#   Special_Conditions_at_Site Carriageway_Hazards Urban_or_Rural_Area
# 0               Ol or diesel                None                   1
# 1                       None                None                   1
# 2                       None                None                   1
# 3                  Roadworks                None                   1
# 4                       None                None                   1
#
# [5 rows x 21 columns]

# %%
poc=["Pedestrian_Crossing-Human_Control","Pedestrian_Crossing-Physical_Facilities","Weather_Conditions","Road_Surface_Conditions","Special_Conditions_at_Site","Carriageway_Hazards","Road_Type"]

# %%
abc[poc]=abc[poc].apply(label_encoder.fit_transform)

# %%
abc.head()
# Out:
#    Accident_ID  Police_Force  Number_of_Vehicles  Number_of_Casualties  \
# 0            1            34                   2                     1
# 1            2             5                   2                     1
# 2            3             1                   2                     1
# 3            4             1                   1                     1
# 4            5            46                   1                     1
#
#    Day_of_Week   Time  Local_Authority_(District)  1st_Road_Class  \
# 0            7  13:20                         344               4
# 1            4   7:53                         102               3
# 2            4  16:00                         531               6
# 3            1  16:50                           7               6
# 4            3  13:25                         519               3
#
#    1st_Road_Number  Road_Type  ...  2nd_Road_Class  2nd_Road_Number  \
# 0              395          3  ...              -1                0
# 1               13          1  ...              -1                0
# 2                8          2  ...               6                0
# 3               13          3  ...               6                0
# 4               24          0  ...               6                0
#
#    Pedestrian_Crossing-Human_Control  Pedestrian_Crossing-Physical_Facilities  \
# 0                                  2                                        2
# 1                                  2                                        2
# 2                                  2                                        4
# 3                                  2                                        2
# 4                                  2                                        4
#
#    Light_Conditions  Weather_Conditions  Road_Surface_Conditions  \
# 0                 4                   1                        0
# 1                 4                   5                        0
# 2                 4                   1                        0
# 3                 4                   1                        0
# 4                 4                   1                        0
#
#    Special_Conditions_at_Site  Carriageway_Hazards  Urban_or_Rural_Area
# 0                           4                    3                    1
# 1                           3                    3                    1
# 2                           3                    3                    1
# 3                           7                    3                    1
# 4                           3                    3                    1
#
# [5 rows x 21 columns]

# %%
abc.dtypes
# Out:
# Accident_ID                                 int64
# Police_Force                                int64
# Number_of_Vehicles                          int64
# Number_of_Casualties                        int64
# Day_of_Week                                 int64
# Time                                       object
# Local_Authority_(District)                  int64
# 1st_Road_Class                              int64
# 1st_Road_Number                             int64
# Road_Type                                   int32
# Speed_limit                                 int64
# 2nd_Road_Class                              int64
# 2nd_Road_Number                             int64
# Pedestrian_Crossing-Human_Control           int32
# Pedestrian_Crossing-Physical_Facilities     int32
# Light_Conditions                            int32
# Weather_Conditions                          int32
# Road_Surface_Conditions                     int32
# Special_Conditions_at_Site                  int32
# Carriageway_Hazards                         int32
# Urban_or_Rural_Area                         int64
# dtype: object

# %%
abc.drop(["Time"]
  ,axis= 1, inplace=True)

# %%
abc1 = abc.sample(n= 10000)

# %%
x = abc1.drop(["Number_of_Casualties"],axis=1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(x)
X = X.reshape((1000,190))
X = X.transpose()

# %%
abc1.shape
# Out:
# (10000, 20)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y.sample(n= 190),random_state = 0,train_size=0.75,test_size=0.25)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model

regr = linear_model.LinearRegression()
regr.fit(X_train,y_train)
y_pred = regr.predict(X_train)

# %%
print("R squared: {}".format(r2_score(y_true=y_train,y_pred=y_pred)))
# Out:
# R squared: 0.9673182637822674

# %%
residuals = y_train.values-y_pred
mean_residuals = np.mean(residuals)
print("Mean of Residuals {}".format(mean_residuals))
# Very close to zero so all good here.
# Out:
# Mean of Residuals 0.0016978089238557073

# %%
p = sns.scatterplot(y_pred,residuals)
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot([0,26],[0,0],color='blue')
p = plt.title('Residuals vs fitted values plot for homoscedasticity check')

# %%
#Now we will be applying tests.
#A tip is to keep in mind that if we want 95% confidence on our findings and tests then the p-value should be less than 0.05 to be able to reject the null hypothesis. Remember, a researcher or data scientist would always aim to reject the null hypothesis.



#Goldfeld Quandt Test
#-------------------------------------
#Checking heteroscedasticity : Using Goldfeld Quandt we test for heteroscedasticity.

#Null Hypothesis: Error terms are homoscedastic

#Alternative Hypothesis: Error terms are heteroscedastic.#

# %%
import statsmodels.stats.api as sms
from statsmodels.compat import lzip
name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(residuals, X_train)
lzip(name, test)
# Out:
# [('F statistic', 10.70943771285694), ('p-value', 0.012887723229380333)]

# %%
#Since p value is more than 0.05 in Goldfeld Quandt Test, we can't reject it's null hypothesis that error terms are homoscedastic. Good.


#Bartlett’s test tests the null hypothesis that all input samples are from populations with equal variances.

# %%
from scipy.stats import bartlett
test = bartlett(X_train[0],residuals)
print(test)
# Out:
# BartlettResult(statistic=357.04101986310593, pvalue=1.2413683395244533e-79)

# %%
#If p value is quite less than 0.05 in Bartlett, it's null hypothesis that error terms are homoscedastic gets rejected, that's not good for a regression.

# %%
p = sns.distplot(residuals,kde=True)
p = plt.title('Normality of error terms/residuals')

# %%
#The residual terms are pretty much normally distributed for the number of test points we took. Remember the central limit theorem which says that as the sample size increases the distribution tends to be normal. A skew is also visible from the plot. It's very difficult to get perfect curves, distributions in real life data.

#No autocorrelation of residuals
#When the residuals are autocorrelated, it means that the current value is dependent of the previous (historic) values and that there is a definite unexplained pattern in the Y variable that shows up in the error terms. Though it is more evident in time series data.

#In plain terms autocorrelation takes place when there's a pattern in the rows of the data. This is usual in time series data as there is a pattern of time for eg. Week of the day effect which is a very famous pattern seen in stock markets where people tend to buy stocks more towards the beginning of weekends and tend to sell more on Mondays. There's been great study about this phenomenon and it is still a matter of research as to what actual factors cause this trend.

#There should not be autocorrelation in the data so the error terms should not form any pattern.

# %%
plt.figure(figsize=(10,5))
p = sns.lineplot(y_pred,residuals,marker='o',color='blue')
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot([0,26],[0,0],color='red')
p = plt.title('Residuals vs fitted values plot for autocorrelation check')

# %%
#Checking for autocorrelation To ensure the absence of autocorrelation we use Ljungbox test.

#Null Hypothesis: Autocorrelation is absent.

#Alternative Hypothesis: Autocorrelation is present.

# %%
from statsmodels.stats import diagnostic as diag
min(diag.acorr_ljungbox(residuals , lags = 40)[1])
#Since p value is less than 0.05 we reject the null hypothesis that error terms are not autocorrelated.
# Out:
# 0.8846465661671856

# %%
import statsmodels.api as sm

# %%
# autocorrelation
sm.graphics.tsa.plot_acf(residuals, lags=40)
plt.show()

# %%
# partial autocorrelation
sm.graphics.tsa.plot_pacf(residuals, lags=40)
plt.show()

# %%
#The results show signs of autocorelation since there are spikes outside the red confidence interval region. This could be a factor of seasonality in the data.

#No perfect multicollinearity
#In regression, multicollinearity refers to the extent to which independent variables are correlated. Multicollinearity affects the coefficients and p-values, but it does not influence the predictions, precision of the predictions, and the goodness-of-fit statistics.

#If your primary goal is to make predictions, and you don’t need to understand the role of each independent variable, you don’t need to reduce severe multicollinearity

# %%
plt.figure(figsize=(20,20))  # on this line I just set the size of figure to 12 by 10.
p=sns.heatmap(abc.corr(), annot=True,cmap='RdYlGn',square=True)  # seaborn has very simple solution for heatmap

# %%
#Look for correlation of rows where the dependent variable  is not involved because if a variable is correlated with the dependent variable then this would be a good sign for our model. Correlation within dependent variables is what we need to look for and avoid. This data doesn't contain perfect multicollinearity among independent variables. In case there was any then we would try to remove one of the correlated variables depending on which was more important to our regression model

# %%
## Some other model evaluations

# %%
## Decision Tree

from sklearn.tree import DecisionTreeRegressor

dec_tree = DecisionTreeRegressor(random_state=0)
dec_tree.fit(X_train,y_train)
dec_tree_y_pred = dec_tree.predict(X_train)
print("Accuracy: {}".format(dec_tree.score(X_train,y_train)))
print("R squared: {}".format(r2_score(y_true=y_train,y_pred=dec_tree_y_pred)))
# Out:
# Accuracy: 0.968018018018018
# R squared: 0.968018018018018

# %%
#Random Forest

from sklearn.ensemble import RandomForestRegressor

rf_tree = RandomForestRegressor(random_state=0)
rf_tree.fit(X_train,y_train)
rf_tree_y_pred = rf_tree.predict(X_train)
print("Accuracy: {}".format(rf_tree.score(X_train,y_train)))
print("R squared: {}".format(r2_score(y_true=y_train,y_pred=rf_tree_y_pred)))
# Out:
# Accuracy: 0.8306124987310952
# R squared: 0.8306124987310952

# %%
# SVM

from sklearn.svm import SVR

svr = SVR()
svr.fit(X_train,y_train)
svr_y_pred = svr.predict(X_train)
print("Accuracy: {}".format(svr.score(X_train,y_train)))
print("R squared: {}".format(r2_score(y_true=y_train,y_pred=svr_y_pred)))
# Out:
# Accuracy: 0.650262508181283
# R squared: 0.650262508181283
